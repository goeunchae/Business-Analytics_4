# %%
import pandas as pd
data = pd.read_csv('../data/waterQuality1.csv')
data
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
data.rename(columns={'is_safe':'y'},inplace=True)
data['y'].value_counts()
# Out:
# 0        7084
# 1         912
# #NUM!       3
# Name: y, dtype: int64

# %%
tmp = data[data['y']=='#NUM!'].index
data = data.drop(tmp)

# %%
data.rename(columns={'is_safe':'y'},inplace=True)
data['y'] = pd.to_numeric(data['y'])

# %%
data.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_d09b2_row0_col0, #T_d09b2_row0_col1, #T_d09b2_row0_col2, #T_d09b2_row0_col3, #T_d09b2_row0_col4, #T_d09b2_row0_col5, #T_d09b2_row0_col6, #T_d09b2_row0_col7, #T_d09b2_row0_col8, #T_d09b2_row0_col9, #T_d09b2_row0_col10, #T_d09b2_row0_col11, #T_d09b2_row0_col12, #T_d09b2_row0_col13, #T_d09b2_row0_col14, #T_d09b2_row0_col15, #T_d09b2_row0_col16, #T_d09b2_row0_col17, #T_d09b2_row0_col18, #T_d09b2_row0_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(18,18))
sns.heatmap(data.corr(),annot=True,center = 0,cmap="YlGnBu")
plt.show()

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(data.select_dtypes(include=['float64']).columns):
    plt.rcParams['axes.facecolor'] = 'white'
    ax = plt.subplot(4,5, i+1)
    sns.barplot(data=data, x='y', y=col, ax=ax,edgecolor="white",palette='viridis_r')
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %%
data.to_csv('../data/data_3.csv',index=False)
